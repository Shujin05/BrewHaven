# %%
# import libraries
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# load datasets
sales_reciepts = pd.read_csv("dataset/201904 sales reciepts.csv")
sales_reciepts.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    transaction_id transaction_date transaction_time  sales_outlet_id  \
# 0               7       2019-04-01         12:04:43                3
# 1              11       2019-04-01         15:54:39                3
# 2              19       2019-04-01         14:34:59                3
# 3              32       2019-04-01         16:06:04                3
# 4              33       2019-04-01         19:18:37                3
#
#    staff_id  customer_id instore_yn  order  line_item_id  product_id  \
# 0        12          558          N      1             1          52
# 1        17          781          N      1             1          27
# 2        17          788          Y      1             1          46
# 3        12          683          N      1             1          23
# 4        17           99          Y      1             1          34
#
#    quantity  line_item_amount  unit_price promo_item_yn
# 0         1              2.50        2.50             N
# 1         2              7.00        3.50             N
# 2         2              5.00        2.50             N
# 3         2              5.00        2.50             N
# 4         1              2.45        2.45             N

# %%
product = pd.read_csv("dataset/product.csv")
product.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    product_id    product_group product_category       product_type  \
# 0           1  Whole Bean/Teas     Coffee beans      Organic Beans
# 1           2  Whole Bean/Teas     Coffee beans  House blend Beans
# 2           3  Whole Bean/Teas     Coffee beans     Espresso Beans
# 3           4  Whole Bean/Teas     Coffee beans     Espresso Beans
# 4           5  Whole Bean/Teas     Coffee beans      Gourmet Beans
#
#                     product  \
# 0       Brazilian - Organic
# 1  Our Old Time Diner Blend
# 2            Espresso Roast
# 3      Primo Espresso Roast
# 4    Columbian Medium Roast
#
#                                  product_description unit_of_measure  \
# 0     It's like Carnival in a cup. Clean and smooth.           12 oz
# 1  Out packed blend of beans that is reminiscent ...           12 oz
# 2          Our house blend for a good espresso shot.            1 lb
# 3   Our primium single source of hand roasted beans.            1 lb
# 4           A smooth cup of coffee any time of day.             1 lb
#
#    current_wholesale_price current_retail_price tax_exempt_yn promo_yn  \
# 0                    14.40              $18.00              Y        N
# 1                    14.40              $18.00              Y        N
# 2                    11.80              $14.75              Y        N
# 3                    16.36              $20.45              Y        N
# 4                    12.00              $15.00              Y        N
#
#   new_product_yn
# 0              N
# 1              N
# 2              N
# 3              N
# 4              N

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ## Merge Data

# %%
sales_reciepts = sales_reciepts[["transaction_id", "transaction_date", "sales_outlet_id", "customer_id", "product_id", "quantity"]]
product = product[["product_id", "product_category", "product"]]

dataset = pd.merge(sales_reciepts, product, on="product_id", how="left")
dataset.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    transaction_id transaction_date  sales_outlet_id  customer_id  product_id  \
# 0               7       2019-04-01                3          558          52
# 1              11       2019-04-01                3          781          27
# 2              19       2019-04-01                3          788          46
# 3              32       2019-04-01                3          683          23
# 4              33       2019-04-01                3           99          34
#
#    quantity product_category                      product
# 0         1              Tea    Traditional Blend Chai Rg
# 1         2           Coffee                 Brazilian Lg
# 2         2              Tea        Serenity Green Tea Rg
# 3         2           Coffee  Our Old Time Diner Blend Rg
# 4         1           Coffee     Jamaican Coffee River Sm

# %%
#obtain unique products
dataset["product"].unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['Traditional Blend Chai Rg', 'Brazilian Lg',
#        'Serenity Green Tea Rg', 'Our Old Time Diner Blend Rg',
#        'Jamaican Coffee River Sm', 'Ethiopia Rg', 'English Breakfast Lg',
#        'Sustainably Grown Organic Rg', 'Earl Grey Lg',
#        'Jamaican Coffee River Rg', 'Serenity Green Tea Lg',
#        'Brazilian Sm', 'English Breakfast Rg',
#        'Traditional Blend Chai Lg', 'Cappuccino', 'Espresso shot',
#        'Cappuccino Lg', 'Latte', 'Earl Grey Rg', 'Dark chocolate Lg',
#        'Columbian Medium Roast Sm', 'Oatmeal Scone',
#        'Morning Sunrise Chai Lg', 'Morning Sunrise Chai Rg',
#        'Peppermint Lg', 'Jumbo Savory Scone', 'Lemon Grass Lg',
#        'Sustainably Grown Organic Lg', 'Dark chocolate Rg',
#        'Lemon Grass Rg', 'Ethiopia Sm', 'Latte Rg',
#        'Our Old Time Diner Blend Sm', 'Chocolate Chip Biscotti',
#        'Columbian Medium Roast Rg', 'Ethiopia Lg', 'Brazilian Rg',
#        'Columbian Medium Roast Lg', 'Spicy Eye Opener Chai Rg',
#        'Ginger Biscotti', 'Our Old Time Diner Blend Lg',
#        'Chocolate Croissant', 'Jamaican Coffee River Lg',
#        'Hazelnut Biscotti', 'Spicy Eye Opener Chai Lg', 'Cranberry Scone',
#        'Peppermint Rg', 'Scottish Cream Scone ', 'Croissant',
#        'Almond Croissant', 'Ginger Scone', 'Ouro Brasileiro shot',
#        'Organic Decaf Blend', 'Chocolate syrup', 'Peppermint', 'Ethiopia',
#        'Hazelnut syrup', 'Carmel syrup', 'English Breakfast',
#        'Sugar Free Vanilla syrup', 'Our Old Time Diner Blend',
#        'Jamacian Coffee River', 'Spicy Eye Opener Chai',
#        'Sustainably Grown Organic', 'Dark chocolate',
#        'Guatemalan Sustainably Grown', 'Civet Cat', 'Serenity Green Tea',
#        'Chili Mayan', 'Primo Espresso Roast', 'Brazilian - Organic',
#        'Morning Sunrise Chai', 'Earl Grey', 'I Need My Bean! Diner mug',
#        'Traditional Blend Chai', 'Espresso Roast',
#        'Columbian Medium Roast', 'I Need My Bean! T-shirt',
#        'I Need My Bean! Latte cup', 'Lemon Grass'], dtype=object)

# %%
# remove sizes
dataset["product"] = dataset["product"].str.replace(" Rg", '')
dataset["product"] = dataset["product"].str.replace(" Lg", '')
dataset["product"] = dataset["product"].str.replace(" Sm", '')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dataset["product"].nunique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 45

# %%
dataset["product"].unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['Traditional Blend Chai', 'Brazilian', 'Serenity Green Tea',
#        'Our Old Time Diner Blend', 'Jamaican Coffee River', 'Ethiopia',
#        'English Breakfast', 'Sustainably Grown Organic', 'Earl Grey',
#        'Cappuccino', 'Espresso shot', 'Latte', 'Dark chocolate',
#        'Columbian Medium Roast', 'Oatmeal Scone', 'Morning Sunrise Chai',
#        'Peppermint', 'Jumbo Savory Scone', 'Lemon Grass',
#        'Chocolate Chip Biscotti', 'Spicy Eye Opener Chai',
#        'Ginger Biscotti', 'Chocolate Croissant', 'Hazelnut Biscotti',
#        'Cranberry Scone', 'Scottish Cream Scone ', 'Croissant',
#        'Almond Croissant', 'Ginger Scone', 'Ouro Brasileiro shot',
#        'Organic Decaf Blend', 'Chocolate syrup', 'Hazelnut syrup',
#        'Carmel syrup', 'Sugar Free Vanilla syrup',
#        'Jamacian Coffee River', 'Guatemalan Sustainably Grown',
#        'Civet Cat', 'Chili Mayan', 'Primo Espresso Roast',
#        'Brazilian - Organic', 'I Need My Bean! Diner mug',
#        'Espresso Roast', 'I Need My Bean! T-shirt',
#        'I Need My Bean! Latte cup'], dtype=object)

# %%
# filter out unrelated products (coffee beans and t-shirt)
products_stock = ['Cappuccino', 'Latte', 'Espresso shot', 'Dark chocolate',
                  'Sugar Free Vanilla syrup', 'Carmel syrup', 'Chocolate syrup',
                  'Hazelnut syrup', 'Ginger Scone', 'Chocolate Croissant', 'Jumbo Savory Scone',
                  'Cranberry Scone', 'Hazelnut Biscotti', 'Croissant', 'Almond Croissant',
                  'Oatmeal Scone', 'Chocolate Chip Biscotti', 'Ginger Biscotti']

dataset = dataset[dataset["product"].isin(products_stock)]
dataset.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     transaction_id transaction_date  sales_outlet_id  customer_id  product_id  \
# 16             108       2019-04-01                3           65          40
# 17             112       2019-04-01                3           90          37
# 20             127       2019-04-01                3          116          41
# 21             134       2019-04-01                3          189          38
# 22             135       2019-04-01                3          131          40
#
#     quantity product_category        product
# 16         1           Coffee     Cappuccino
# 17         2           Coffee  Espresso shot
# 20         2           Coffee     Cappuccino
# 21         2           Coffee          Latte
# 22         1           Coffee     Cappuccino

# %%
dataset[['product', 'product_category']].drop_duplicates().reset_index(drop=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                      product    product_category
# 0                 Cappuccino              Coffee
# 1              Espresso shot              Coffee
# 2                      Latte              Coffee
# 3             Dark chocolate  Drinking Chocolate
# 4              Oatmeal Scone              Bakery
# 5         Jumbo Savory Scone              Bakery
# 6    Chocolate Chip Biscotti              Bakery
# 7            Ginger Biscotti              Bakery
# 8        Chocolate Croissant              Bakery
# 9          Hazelnut Biscotti              Bakery
# 10           Cranberry Scone              Bakery
# 11                 Croissant              Bakery
# 12          Almond Croissant              Bakery
# 13              Ginger Scone              Bakery
# 14           Chocolate syrup            Flavours
# 15            Hazelnut syrup            Flavours
# 16              Carmel syrup            Flavours
# 17  Sugar Free Vanilla syrup            Flavours
# 18            Dark chocolate  Packaged Chocolate

# %% [markdown]
# ### Clean Transactions

# %%
dataset["transaction"] = dataset["transaction_id"].astype(str) + "_" + dataset["customer_id"].astype(str)
dataset.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     transaction_id transaction_date  sales_outlet_id  customer_id  product_id  \
# 16             108       2019-04-01                3           65          40
# 17             112       2019-04-01                3           90          37
# 20             127       2019-04-01                3          116          41
# 21             134       2019-04-01                3          189          38
# 22             135       2019-04-01                3          131          40
#
#     quantity product_category        product transaction
# 16         1           Coffee     Cappuccino      108_65
# 17         2           Coffee  Espresso shot      112_90
# 20         2           Coffee     Cappuccino     127_116
# 21         2           Coffee          Latte     134_189
# 22         1           Coffee     Cappuccino     135_131

# %%
num_of_items_per_transaction = dataset['transaction'].value_counts().reset_index()
num_of_items_per_transaction.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   transaction  count
# 0       209_0     31
# 1       206_0     30
# 2       204_0     27
# 3       208_0     25
# 4       203_0     24

# %%
valid_transactions = num_of_items_per_transaction[num_of_items_per_transaction["count"] > 1]['transaction']
valid_transactions.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0    209_0
# 1    206_0
# 2    204_0
# 3    208_0
# 4    203_0
# Name: transaction, dtype: object

# %%
valid_transactions_lst = valid_transactions.tolist()
print(valid_transactions_lst[:5])
# Out:
# ['209_0', '206_0', '204_0', '208_0', '203_0']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dataset = dataset[dataset['transaction'].isin(valid_transactions_lst)]
dataset.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (10189, 9)

# %% [markdown]
# ### Analysing Product Trends

# %%
dataset["product"].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product
# Cappuccino                  1290
# Latte                       1256
# Dark chocolate               969
# Chocolate Croissant          636
# Espresso shot                628
# Sugar Free Vanilla syrup     605
# Chocolate syrup              568
# Carmel syrup                 561
# Hazelnut syrup               512
# Ginger Scone                 417
# Jumbo Savory Scone           357
# Croissant                    355
# Chocolate Chip Biscotti      352
# Cranberry Scone              350
# Almond Croissant             347
# Hazelnut Biscotti            338
# Oatmeal Scone                334
# Ginger Biscotti              314
# Name: count, dtype: int64

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Recommendation Engine based on Popularity

# %%
product_recommendation = dataset.groupby(["product", "product_category",]).count().reset_index()
product_recommendation.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                    product product_category  transaction_id  transaction_date  \
# 0         Almond Croissant           Bakery             347               347
# 1               Cappuccino           Coffee            1290              1290
# 2             Carmel syrup         Flavours             561               561
# 3  Chocolate Chip Biscotti           Bakery             352               352
# 4      Chocolate Croissant           Bakery             636               636
#
#    sales_outlet_id  customer_id  product_id  quantity  transaction
# 0              347          347         347       347          347
# 1             1290         1290        1290      1290         1290
# 2              561          561         561       561          561
# 3              352          352         352       352          352
# 4              636          636         636       636          636

# %%
product_recommendation = product_recommendation[["product", "product_category", "transaction_id"]]
product_recommendation.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                    product product_category  transaction_id
# 0         Almond Croissant           Bakery             347
# 1               Cappuccino           Coffee            1290
# 2             Carmel syrup         Flavours             561
# 3  Chocolate Chip Biscotti           Bakery             352
# 4      Chocolate Croissant           Bakery             636

# %%
product_recommendation.to_csv('api/popularity.csv', index = False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Apriori Recommendation Engine

# %%
train_basket = (dataset.groupby(['transaction', 'product'])['product'].count().reset_index(name="count"))
train_basket.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   transaction         product  count
# 0      1000_0  Dark chocolate      1
# 1      1000_0   Oatmeal Scone      1
# 2   1001_8306      Cappuccino      1
# 3   1001_8306    Carmel syrup      1
# 4      1002_0    Carmel syrup      1

# %%
# convert train_basket to wide format
my_basket = train_basket.pivot_table(index='transaction', columns='product', values='count').fillna(0)
my_basket.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product      Almond Croissant  Cappuccino  Carmel syrup  \
# transaction
# 1000_0                    0.0         0.0           0.0
# 1001_8306                 0.0         1.0           1.0
# 1002_0                    0.0         0.0           1.0
# 1004_5383                 0.0         0.0           0.0
# 1005_0                    0.0         0.0           0.0
#
# product      Chocolate Chip Biscotti  Chocolate Croissant  Chocolate syrup  \
# transaction
# 1000_0                           0.0                  0.0              0.0
# 1001_8306                        0.0                  0.0              0.0
# 1002_0                           0.0                  0.0              0.0
# 1004_5383                        0.0                  0.0              1.0
# 1005_0                           0.0                  0.0              0.0
#
# product      Cranberry Scone  Croissant  Dark chocolate  Espresso shot  \
# transaction
# 1000_0                   0.0        0.0             1.0            0.0
# 1001_8306                0.0        0.0             0.0            0.0
# 1002_0                   0.0        0.0             2.0            1.0
# 1004_5383                0.0        0.0             0.0            0.0
# 1005_0                   0.0        0.0             0.0            0.0
#
# product      Ginger Biscotti  Ginger Scone  Hazelnut Biscotti  Hazelnut syrup  \
# transaction
# 1000_0                   0.0           0.0                0.0             0.0
# 1001_8306                0.0           0.0                0.0             0.0
# 1002_0                   0.0           1.0                0.0             0.0
# 1004_5383                0.0           0.0                0.0             0.0
# 1005_0                   0.0           0.0                0.0             0.0
#
# product      Jumbo Savory Scone  Latte  Oatmeal Scone  \
# transaction
# 1000_0                      0.0    0.0            1.0
# 1001_8306                   0.0    0.0            0.0
# 1002_0                      0.0    0.0            0.0
# 1004_5383                   0.0    1.0            0.0
# 1005_0                      2.0    1.0            0.0
#
# product      Sugar Free Vanilla syrup
# transaction
# 1000_0                            0.0
# 1001_8306                         0.0
# 1002_0                            0.0
# 1004_5383                         0.0
# 1005_0                            0.0

# %%
def encode_units(x):
  if x <= 0:
    return 0
  if x >= 1:
    return 1

my_basket_sets = my_basket.applymap(encode_units)
my_basket_sets.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-66-4f9697e4466e>:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   my_basket_sets = my_basket.applymap(encode_units)
# product      Almond Croissant  Cappuccino  Carmel syrup  \
# transaction
# 1000_0                      0           0             0
# 1001_8306                   0           1             1
# 1002_0                      0           0             1
# 1004_5383                   0           0             0
# 1005_0                      0           0             0
#
# product      Chocolate Chip Biscotti  Chocolate Croissant  Chocolate syrup  \
# transaction
# 1000_0                             0                    0                0
# 1001_8306                          0                    0                0
# 1002_0                             0                    0                0
# 1004_5383                          0                    0                1
# 1005_0                             0                    0                0
#
# product      Cranberry Scone  Croissant  Dark chocolate  Espresso shot  \
# transaction
# 1000_0                     0          0               1              0
# 1001_8306                  0          0               0              0
# 1002_0                     0          0               1              1
# 1004_5383                  0          0               0              0
# 1005_0                     0          0               0              0
#
# product      Ginger Biscotti  Ginger Scone  Hazelnut Biscotti  Hazelnut syrup  \
# transaction
# 1000_0                     0             0                  0               0
# 1001_8306                  0             0                  0               0
# 1002_0                     0             1                  0               0
# 1004_5383                  0             0                  0               0
# 1005_0                     0             0                  0               0
#
# product      Jumbo Savory Scone  Latte  Oatmeal Scone  \
# transaction
# 1000_0                        0      0              1
# 1001_8306                     0      0              0
# 1002_0                        0      0              0
# 1004_5383                     0      1              0
# 1005_0                        1      1              0
#
# product      Sugar Free Vanilla syrup
# transaction
# 1000_0                              0
# 1001_8306                           0
# 1002_0                              0
# 1004_5383                           0
# 1005_0                              0

# %%
frequent_items = apriori(my_basket_sets, min_support=0.05, use_colnames=True)
frequent_items.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                   itemsets
# 0  0.115646         (Almond Croissant)
# 1  0.388889               (Cappuccino)
# 2  0.191232             (Carmel syrup)
# 3  0.112623  (Chocolate Chip Biscotti)
# 4  0.135676      (Chocolate Croissant)

# %%
rules_basket = association_rules(frequent_items, metric = "lift", min_threshold=1, num_itemsets = 1)
rules_basket.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           antecedents         consequents  antecedent support  \
# 0  (Almond Croissant)        (Cappuccino)            0.115646
# 1        (Cappuccino)  (Almond Croissant)            0.388889
# 2    (Dark chocolate)  (Almond Croissant)            0.277022
# 3  (Almond Croissant)    (Dark chocolate)            0.115646
# 4  (Almond Croissant)             (Latte)            0.115646
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.388889  0.053288    0.460784  1.184874               1.0
# 1            0.115646  0.053288    0.137026  1.184874               1.0
# 2            0.115646  0.057445    0.207367  1.793115               1.0
# 3            0.277022  0.057445    0.496732  1.793115               1.0
# 4            0.382086  0.054422    0.470588  1.231629               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.008314    1.133333       0.176432  0.118090   0.117647    0.298905
# 1  0.008314    1.024775       0.255319  0.118090   0.024176    0.298905
# 2  0.025409    1.115717       0.611791  0.171364   0.103715    0.352050
# 3  0.025409    1.436567       0.500152  0.171364   0.303896    0.352050
# 4  0.010235    1.167171       0.212660  0.122762   0.143227    0.306511

# %%
rules_basket[rules_basket["antecedents"] == {"Cappuccino"}].sort_values('confidence', ascending = False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      antecedents                 consequents  antecedent support  \
# 27  (Cappuccino)  (Sugar Free Vanilla syrup)            0.388889
# 13  (Cappuccino)           (Chocolate syrup)            0.388889
# 7   (Cappuccino)              (Carmel syrup)            0.388889
# 23  (Cappuccino)            (Hazelnut syrup)            0.388889
# 20  (Cappuccino)              (Ginger Scone)            0.388889
# 9   (Cappuccino)   (Chocolate Chip Biscotti)            0.388889
# 11  (Cappuccino)       (Chocolate Croissant)            0.388889
# 16  (Cappuccino)                 (Croissant)            0.388889
# 24  (Cappuccino)        (Jumbo Savory Scone)            0.388889
# 18  (Cappuccino)           (Ginger Biscotti)            0.388889
# 1   (Cappuccino)          (Almond Croissant)            0.388889
# 15  (Cappuccino)           (Cranberry Scone)            0.388889
#
#     consequent support   support  confidence      lift  representativity  \
# 27            0.200302  0.113001    0.290573  1.450674               1.0
# 13            0.188964  0.109599    0.281827  1.491429               1.0
# 7             0.191232  0.102797    0.264334  1.382270               1.0
# 23            0.171580  0.090325    0.232264  1.353682               1.0
# 20            0.133409  0.059713    0.153547  1.150951               1.0
# 9             0.112623  0.056311    0.144801  1.285714               1.0
# 11            0.135676  0.056311    0.144801  1.067250               1.0
# 16            0.114135  0.056311    0.144801  1.268685               1.0
# 24            0.114890  0.055178    0.141885  1.234962               1.0
# 18            0.106198  0.053666    0.137998  1.299441               1.0
# 1             0.115646  0.053288    0.137026  1.184874               1.0
# 15            0.116024  0.052532    0.135083  1.164262               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 27  0.035105    1.127245       0.508361  0.237302   0.112881    0.427362
# 13  0.036113    1.129304       0.539185  0.234060   0.114499    0.430914
# 7   0.028429    1.099369       0.452540  0.215360   0.090387    0.400942
# 23  0.023600    1.079044       0.427539  0.192122   0.073253    0.379348
# 20  0.007832    1.023791       0.214614  0.129085   0.023238    0.300570
# 9   0.012514    1.037626       0.363636  0.126486   0.036262    0.322400
# 11  0.003548    1.010669       0.103112  0.120258   0.010557    0.279921
# 16  0.011926    1.035859       0.346553  0.126058   0.034617    0.319089
# 24  0.010498    1.031458       0.311333  0.122999   0.030499    0.311074
# 18  0.012367    1.036891       0.377081  0.121575   0.035578    0.321668
# 1   0.008314    1.024775       0.255319  0.118090   0.024176    0.298905
# 15  0.007412    1.022035       0.230870  0.116124   0.021560    0.293926

# %% [markdown]
# ## Save in JSON Format

# %%
product_categories = dataset[['product', 'product_category']].drop_duplicates().set_index('product').to_dict()['product_category']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
recommendations_json = {}

antecedents = rules_basket['antecedents'].unique()
for antecedent in antecedents:
  df_rec = rules_basket[rules_basket["antecedents"]==antecedent]
  df_rec = df_rec.sort_values('confidence', ascending=False)

  key = '_'.join(antecedent)
  recommendations_json[key] = []
  for _, row in df_rec.iterrows():
    rec_objects = row['consequents']
    for rec_object in rec_objects:
      already_exists=False
      for current_rec_object in recommendations_json[key]:
        if rec_object == current_rec_object['product']:
          already_exists=True
      if already_exists:
        continue
      rec = {
          "product": rec_object,
          "product_category": product_categories[rec_object],
          "confidence": row['confidence'],
        }
      recommendations_json[key].append(rec)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pprint
pprint.pp(recommendations_json)
# Out:
# {'Almond Croissant': [{'product': 'Dark chocolate',
#                        'product_category': 'Packaged Chocolate',
#                        'confidence': 0.4967320261437908},
#                       {'product': 'Latte',
#                        'product_category': 'Coffee',
#                        'confidence': 0.47058823529411764},
#                       {'product': 'Cappuccino',
#                        'product_category': 'Coffee',
#                        'confidence': 0.46078431372549017}],
#  'Cappuccino': [{'product': 'Sugar Free Vanilla syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.29057337220602525},
#                 {'product': 'Chocolate syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.2818270165208941},
#                 {'product': 'Carmel syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.26433430515063167},
#                 {'product': 'Hazelnut syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.23226433430515062},
#                 {'product': 'Ginger Scone',
#                  'product_category': 'Bakery',
#                  'confidence': 0.15354713313896987},
#                 {'product': 'Chocolate Chip Biscotti',
#                  'product_category': 'Bakery',
#                  'confidence': 0.14480077745383868},
#                 {'product': 'Chocolate Croissant',
#                  'product_category': 'Bakery',
#                  'confidence': 0.14480077745383868},
#                 {'product': 'Croissant',
#                  'product_category': 'Bakery',
#                  'confidence': 0.14480077745383868},
#                 {'product': 'Jumbo Savory Scone',
#                  'product_category': 'Bakery',
#                  'confidence': 0.14188532555879496},
#                 {'product': 'Ginger Biscotti',
#                  'product_category': 'Bakery',
#                  'confidence': 0.1379980563654033},
#                 {'product': 'Almond Croissant',
#                  'product_category': 'Bakery',
#                  'confidence': 0.13702623906705538},
#                 {'product': 'Cranberry Scone',
#                  'product_category': 'Bakery',
#                  'confidence': 0.13508260447035958}],
#  'Dark chocolate': [{'product': 'Espresso shot',
#                      'product_category': 'Coffee',
#                      'confidence': 0.22100954979536153},
#                     {'product': 'Chocolate Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.2169167803547067},
#                     {'product': 'Ginger Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.21555252387448842},
#                     {'product': 'Almond Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.20736698499317874},
#                     {'product': 'Cranberry Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.2032742155525239},
#                     {'product': 'Carmel syrup',
#                      'product_category': 'Flavours',
#                      'confidence': 0.19918144611186905},
#                     {'product': 'Chocolate Chip Biscotti',
#                      'product_category': 'Bakery',
#                      'confidence': 0.19372442019099592},
#                     {'product': 'Chocolate syrup',
#                      'product_category': 'Flavours',
#                      'confidence': 0.19099590723055934},
#                     {'product': 'Jumbo Savory Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.18553888130968624},
#                     {'product': 'Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.18417462482946795}],
#  'Latte': [{'product': 'Sugar Free Vanilla syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.28486646884273},
#            {'product': 'Carmel syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.2818991097922849},
#            {'product': 'Chocolate syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.27002967359050445},
#            {'product': 'Hazelnut syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.26508407517309596},
#            {'product': 'Croissant',
#             'product_category': 'Bakery',
#             'confidence': 0.14935707220573688},
#            {'product': 'Chocolate Croissant',
#             'product_category': 'Bakery',
#             'confidence': 0.1444114737883284},
#            {'product': 'Ginger Scone',
#             'product_category': 'Bakery',
#             'confidence': 0.1444114737883284},
#            {'product': 'Almond Croissant',
#             'product_category': 'Bakery',
#             'confidence': 0.142433234421365},
#            {'product': 'Ginger Biscotti',
#             'product_category': 'Bakery',
#             'confidence': 0.1414441147378833},
#            {'product': 'Cranberry Scone',
#             'product_category': 'Bakery',
#             'confidence': 0.13452027695351138}],
#  'Carmel syrup': [{'product': 'Latte',
#                    'product_category': 'Coffee',
#                    'confidence': 0.5632411067193677},
#                   {'product': 'Cappuccino',
#                    'product_category': 'Coffee',
#                    'confidence': 0.5375494071146245},
#                   {'product': 'Espresso shot',
#                    'product_category': 'Coffee',
#                    'confidence': 0.31620553359683795},
#                   {'product': 'Dark chocolate',
#                    'product_category': 'Packaged Chocolate',
#                    'confidence': 0.2885375494071146}],
#  'Chocolate Chip Biscotti': [{'product': 'Cappuccino',
#                               'product_category': 'Coffee',
#                               'confidence': 0.5},
#                              {'product': 'Dark chocolate',
#                               'product_category': 'Packaged Chocolate',
#                               'confidence': 0.47651006711409394}],
#  'Chocolate Croissant': [{'product': 'Dark chocolate',
#                           'product_category': 'Packaged Chocolate',
#                           'confidence': 0.44289693593314766},
#                          {'product': 'Cappuccino',
#                           'product_category': 'Coffee',
#                           'confidence': 0.415041782729805},
#                          {'product': 'Latte',
#                           'product_category': 'Coffee',
#                           'confidence': 0.40668523676880225}],
#  'Chocolate syrup': [{'product': 'Cappuccino',
#                       'product_category': 'Coffee',
#                       'confidence': 0.58},
#                      {'product': 'Latte',
#                       'product_category': 'Coffee',
#                       'confidence': 0.5459999999999999},
#                      {'product': 'Espresso shot',
#                       'product_category': 'Coffee',
#                       'confidence': 0.312},
#                      {'product': 'Dark chocolate',
#                       'product_category': 'Packaged Chocolate',
#                       'confidence': 0.27999999999999997}],
#  'Cranberry Scone': [{'product': 'Dark chocolate',
#                       'product_category': 'Packaged Chocolate',
#                       'confidence': 0.48534201954397393},
#                      {'product': 'Cappuccino',
#                       'product_category': 'Coffee',
#                       'confidence': 0.4527687296416938},
#                      {'product': 'Latte',
#                       'product_category': 'Coffee',
#                       'confidence': 0.4429967426710098}],
#  'Croissant': [{'product': 'Latte',
#                 'product_category': 'Coffee',
#                 'confidence': 0.5},
#                {'product': 'Cappuccino',
#                 'product_category': 'Coffee',
#                 'confidence': 0.49337748344370863},
#                {'product': 'Dark chocolate',
#                 'product_category': 'Packaged Chocolate',
#                 'confidence': 0.4470198675496689}],
#  'Ginger Biscotti': [{'product': 'Latte',
#                       'product_category': 'Coffee',
#                       'confidence': 0.5088967971530249},
#                      {'product': 'Cappuccino',
#                       'product_category': 'Coffee',
#                       'confidence': 0.505338078291815}],
#  'Ginger Scone': [{'product': 'Cappuccino',
#                    'product_category': 'Coffee',
#                    'confidence': 0.4475920679886685},
#                   {'product': 'Dark chocolate',
#                    'product_category': 'Packaged Chocolate',
#                    'confidence': 0.4475920679886685},
#                   {'product': 'Latte',
#                    'product_category': 'Coffee',
#                    'confidence': 0.41359773371104813}],
#  'Hazelnut syrup': [{'product': 'Latte',
#                      'product_category': 'Coffee',
#                      'confidence': 0.5903083700440529},
#                     {'product': 'Cappuccino',
#                      'product_category': 'Coffee',
#                      'confidence': 0.526431718061674},
#                     {'product': 'Espresso shot',
#                      'product_category': 'Coffee',
#                      'confidence': 0.32158590308370044}],
#  'Jumbo Savory Scone': [{'product': 'Cappuccino',
#                          'product_category': 'Coffee',
#                          'confidence': 0.48026315789473684},
#                         {'product': 'Dark chocolate',
#                          'product_category': 'Packaged Chocolate',
#                          'confidence': 0.4473684210526316}],
#  'Sugar Free Vanilla syrup': [{'product': 'Cappuccino',
#                                'product_category': 'Coffee',
#                                'confidence': 0.5641509433962264},
#                               {'product': 'Latte',
#                                'product_category': 'Coffee',
#                                'confidence': 0.5433962264150943},
#                               {'product': 'Espresso shot',
#                                'product_category': 'Coffee',
#                                'confidence': 0.30566037735849055}],
#  'Espresso shot': [{'product': 'Dark chocolate',
#                     'product_category': 'Packaged Chocolate',
#                     'confidence': 0.2924187725631769},
#                    {'product': 'Sugar Free Vanilla syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.2924187725631769},
#                    {'product': 'Carmel syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.2888086642599278},
#                    {'product': 'Chocolate syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.2815884476534296},
#                    {'product': 'Hazelnut syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.26353790613718414}]}
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import json
with open('api/recommendation_objects/apriori_recommendations.json', 'w') as json_file:
  json.dump(recommendations_json, json_file)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
